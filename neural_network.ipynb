# %%
import numpy as np
import torch
import torch.nn as nn
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset

# %%
data = pd.read_csv("diabetes.csv")

# %%
data.head(10)
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                           148
# 1                         1                            85
# 2                         8                           183
# 3                         1                            89
# 4                         0                           137
# 5                         5                           116
# 6                         3                            78
# 7                        10                           115
# 8                         2                           197
# 9                         8                           125
#
#    Diastolic blood pressure  Triceps skin fold thickness  \
# 0                        72                           35
# 1                        66                           29
# 2                        64                            0
# 3                        66                           23
# 4                        40                           35
# 5                        74                            0
# 6                        50                           32
# 7                         0                            0
# 8                        70                           45
# 9                        96                            0
#
#    2-Hour serum insulin  Body mass index  Age     Class
# 0                     0             33.6   50  positive
# 1                     0             26.6   31  negative
# 2                     0             23.3   32  positive
# 3                    94             28.1   21  negative
# 4                   168             43.1   33  positive
# 5                     0             25.6   30  negative
# 6                    88             31.0   26  positive
# 7                     0             35.3   29  negative
# 8                   543             30.5   53  positive
# 9                     0              0.0   54  positive

# %%
x = data.iloc[:,:-1].values
y_str = data.iloc[:,-1].values

# %%
x
# Out:
# array([[  6. , 148. ,  72. , ...,   0. ,  33.6,  50. ],
#        [  1. ,  85. ,  66. , ...,   0. ,  26.6,  31. ],
#        [  8. , 183. ,  64. , ...,   0. ,  23.3,  32. ],
#        ...,
#        [  5. , 121. ,  72. , ..., 112. ,  26.2,  30. ],
#        [  1. , 126. ,  60. , ...,   0. ,  30.1,  47. ],
#        [  1. ,  93. ,  70. , ...,   0. ,  30.4,  23. ]])

# %%
x.shape
# Out:
# (768, 7)

# %%
len(y_str)
# Out:
# 768

# %%
np.unique(y_str)
# Out:
# array(['negative', 'positive'], dtype=object)

# %%
y_int = [1 if s=='positive' else 0 for s in y_str]

# %%
y = np.array(y_int,dtype = "float64")

# %%
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ..., -0.69289057,
#          0.20401277,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.69289057,
#         -0.68442195, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -0.69289057,
#         -1.10325546, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ...,  0.27959377,
#         -0.73518964, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.69289057,
#         -0.24020459,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.69289057,
#         -0.20212881, -0.87137393]])

# %%
x = torch.tensor(x)
y = torch.tensor(y)

# %%
x.shape
# Out:
# torch.Size([768, 7])

# %%
y.shape
# Out:
# torch.Size([768])

# %%
# for binary cross entropy both label and input should be of same dimension ! so we unsqueeze y !!

# %%
y = y.unsqueeze(1) # or y.unsqueeze_(1) and since this is an inplace operation so we don't need to reassign it to y !!

# %% [markdown]
# DO NOT RERUN THE UNSQUEEZE CELL !!! this will create one more dimension !!!

# %%
print(x.shape,y.shape)
# Out:
# torch.Size([768, 7]) torch.Size([768, 1])

# %%
class Dataset(Dataset) : 
    def __init__(self,x,y) :
        self.x = x
        self.y = y
    def __getitem__(self,index) : 
        return self.x[index],self.y[index]
    def __len__(self) :
        return len(self.x)

# %%
dataset = Dataset(x,y)

# %%
len(dataset)
# Out:
# 768

# %%
from torch.utils.data import DataLoader

# %%
train_loader = DataLoader(dataset=dataset,
                          batch_size=32,
                          shuffle = True)

# %%
print(f"There are {len(train_loader)} batches in the dataset")
for (x,y) in train_loader :
    print("for one iteration (batch), there is :")
    print(f"Data : {x.shape}\nLabels : {y.shape}")
    break
# Out:
# There are 24 batches in the dataset
# for one iteration (batch), there is :
# Data : torch.Size([32, 7])
# Labels : torch.Size([32, 1])

# %%
class Model(nn.Module) : # inheritance in python
    def __init__(self,input_features,output_features) : 
        super(Model,self).__init__() # this function just takes the methods of parent class and pass it to inherited class !
        self.fc1 = nn.Linear(input_features,5)
        self.fc2 = nn.Linear(5,4)
        self.fc3 = nn.Linear(4,3)
        self.fc4 = nn.Linear(3,output_features)
        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()
    def forward(self,x):
        out = self.fc1(x)
        out = self.tanh(out) # every layer is activated using tanh()
        out = self.fc2(out)
        out = self.tanh(out)
        out = self.fc3(out)
        out = self.tanh(out)
        out = self.fc4(out)
        out = self.sigmoid(out) # last layer is activated using sigmoid()
        return out

# %%
network = Model(7,1)
criterion = nn.BCELoss(reduction="mean") # earlier, the arg was size_average = True !!
optimizer = torch.optim.SGD(network.parameters(),lr = 0.01, momentum=0.9)

# %%
epochs = 200
for e in range(epochs) : 
    for inputs,labels in train_loader : 
        inputs = inputs.float()
        labels = labels.float()
        # forward pass
        outputs = network(inputs) # or we can just call net.forward(inputs) !!
        loss = criterion(outputs,labels)
        # backward pass
        optimizer.zero_grad()
        loss.backward()
        # update weights
        optimizer.step()
    # accuracy per epoch
    output = (outputs>0.5).float() # > compares correspoding elements !!
    acc = (output==labels).float().mean() # == compares corresponding elements !!
    print(f"epoch no. {e+1} : loss = {loss:.3f}, acc = {acc:.3f}")
# Out:
# epoch no. 1 : loss = 0.672, acc = 0.625
# epoch no. 2 : loss = 0.693, acc = 0.531
# epoch no. 3 : loss = 0.561, acc = 0.781
# epoch no. 4 : loss = 0.552, acc = 0.719
# epoch no. 5 : loss = 0.534, acc = 0.719
# epoch no. 6 : loss = 0.481, acc = 0.875
# epoch no. 7 : loss = 0.631, acc = 0.688
# epoch no. 8 : loss = 0.615, acc = 0.656
# epoch no. 9 : loss = 0.491, acc = 0.781
# epoch no. 10 : loss = 0.429, acc = 0.844
# epoch no. 11 : loss = 0.550, acc = 0.750
# epoch no. 12 : loss = 0.307, acc = 0.875
# epoch no. 13 : loss = 0.465, acc = 0.781
# epoch no. 14 : loss = 0.407, acc = 0.875
# epoch no. 15 : loss = 0.479, acc = 0.781
# epoch no. 16 : loss = 0.615, acc = 0.625
# epoch no. 17 : loss = 0.547, acc = 0.750
# epoch no. 18 : loss = 0.345, acc = 0.875
# epoch no. 19 : loss = 0.378, acc = 0.844
# epoch no. 20 : loss = 0.442, acc = 0.781
# epoch no. 21 : loss = 0.550, acc = 0.688
# epoch no. 22 : loss = 0.605, acc = 0.656
# epoch no. 23 : loss = 0.467, acc = 0.781
# epoch no. 24 : loss = 0.480, acc = 0.750
# epoch no. 25 : loss = 0.427, acc = 0.781
# epoch no. 26 : loss = 0.338, acc = 0.906
# epoch no. 27 : loss = 0.392, acc = 0.781
# epoch no. 28 : loss = 0.616, acc = 0.656
# epoch no. 29 : loss = 0.448, acc = 0.781
# epoch no. 30 : loss = 0.403, acc = 0.812
# epoch no. 31 : loss = 0.567, acc = 0.750
# epoch no. 32 : loss = 0.405, acc = 0.844
# epoch no. 33 : loss = 0.443, acc = 0.812
# epoch no. 34 : loss = 0.505, acc = 0.750
# epoch no. 35 : loss = 0.558, acc = 0.688
# epoch no. 36 : loss = 0.346, acc = 0.875
# epoch no. 37 : loss = 0.485, acc = 0.750
# epoch no. 38 : loss = 0.437, acc = 0.781
# epoch no. 39 : loss = 0.330, acc = 0.812
# epoch no. 40 : loss = 0.547, acc = 0.750
# epoch no. 41 : loss = 0.514, acc = 0.719
# epoch no. 42 : loss = 0.408, acc = 0.812
# epoch no. 43 : loss = 0.562, acc = 0.719
# epoch no. 44 : loss = 0.320, acc = 0.844
# epoch no. 45 : loss = 0.376, acc = 0.812
# epoch no. 46 : loss = 0.414, acc = 0.781
# epoch no. 47 : loss = 0.559, acc = 0.750
# epoch no. 48 : loss = 0.335, acc = 0.844
# epoch no. 49 : loss = 0.410, acc = 0.844
# epoch no. 50 : loss = 0.447, acc = 0.781
# epoch no. 51 : loss = 0.391, acc = 0.844
# epoch no. 52 : loss = 0.524, acc = 0.625
# epoch no. 53 : loss = 0.612, acc = 0.750
# epoch no. 54 : loss = 0.545, acc = 0.719
# epoch no. 55 : loss = 0.404, acc = 0.781
# epoch no. 56 : loss = 0.340, acc = 0.875
# epoch no. 57 : loss = 0.493, acc = 0.719
# epoch no. 58 : loss = 0.528, acc = 0.719
# epoch no. 59 : loss = 0.480, acc = 0.750
# epoch no. 60 : loss = 0.415, acc = 0.688
# epoch no. 61 : loss = 0.500, acc = 0.719
# epoch no. 62 : loss = 0.482, acc = 0.719
# epoch no. 63 : loss = 0.435, acc = 0.781
# epoch no. 64 : loss = 0.496, acc = 0.719
# epoch no. 65 : loss = 0.460, acc = 0.750
# epoch no. 66 : loss = 0.394, acc = 0.844
# epoch no. 67 : loss = 0.576, acc = 0.625
# epoch no. 68 : loss = 0.425, acc = 0.844
# epoch no. 69 : loss = 0.472, acc = 0.750
# epoch no. 70 : loss = 0.256, acc = 0.875
# epoch no. 71 : loss = 0.660, acc = 0.656
# epoch no. 72 : loss = 0.461, acc = 0.719
# epoch no. 73 : loss = 0.488, acc = 0.812
# epoch no. 74 : loss = 0.415, acc = 0.781
# epoch no. 75 : loss = 0.316, acc = 0.812
# epoch no. 76 : loss = 0.610, acc = 0.688
# epoch no. 77 : loss = 0.537, acc = 0.719
# epoch no. 78 : loss = 0.375, acc = 0.812
# epoch no. 79 : loss = 0.645, acc = 0.719
# epoch no. 80 : loss = 0.405, acc = 0.781
# epoch no. 81 : loss = 0.570, acc = 0.750
# epoch no. 82 : loss = 0.291, acc = 0.969
# epoch no. 83 : loss = 0.480, acc = 0.688
# epoch no. 84 : loss = 0.497, acc = 0.781
# epoch no. 85 : loss = 0.392, acc = 0.781
# epoch no. 86 : loss = 0.544, acc = 0.656
# epoch no. 87 : loss = 0.455, acc = 0.719
# epoch no. 88 : loss = 0.432, acc = 0.750
# epoch no. 89 : loss = 0.460, acc = 0.781
# epoch no. 90 : loss = 0.539, acc = 0.750
# epoch no. 91 : loss = 0.407, acc = 0.781
# epoch no. 92 : loss = 0.422, acc = 0.750
# epoch no. 93 : loss = 0.405, acc = 0.812
# epoch no. 94 : loss = 0.335, acc = 0.812
# epoch no. 95 : loss = 0.454, acc = 0.781
# epoch no. 96 : loss = 0.420, acc = 0.781
# epoch no. 97 : loss = 0.331, acc = 0.875
# epoch no. 98 : loss = 0.470, acc = 0.688
# epoch no. 99 : loss = 0.381, acc = 0.781
# epoch no. 100 : loss = 0.303, acc = 0.844
# epoch no. 101 : loss = 0.370, acc = 0.844
# epoch no. 102 : loss = 0.462, acc = 0.781
# epoch no. 103 : loss = 0.435, acc = 0.750
# epoch no. 104 : loss = 0.499, acc = 0.656
# epoch no. 105 : loss = 0.524, acc = 0.688
# epoch no. 106 : loss = 0.354, acc = 0.844
# epoch no. 107 : loss = 0.449, acc = 0.781
# epoch no. 108 : loss = 0.356, acc = 0.844
# epoch no. 109 : loss = 0.487, acc = 0.812
# epoch no. 110 : loss = 0.470, acc = 0.781
# epoch no. 111 : loss = 0.404, acc = 0.812
# epoch no. 112 : loss = 0.438, acc = 0.688
# epoch no. 113 : loss = 0.343, acc = 0.812
# epoch no. 114 : loss = 0.356, acc = 0.844
# epoch no. 115 : loss = 0.304, acc = 0.875
# epoch no. 116 : loss = 0.358, acc = 0.875
# epoch no. 117 : loss = 0.350, acc = 0.844
# epoch no. 118 : loss = 0.495, acc = 0.750
# epoch no. 119 : loss = 0.308, acc = 0.906
# epoch no. 120 : loss = 0.426, acc = 0.688
# epoch no. 121 : loss = 0.400, acc = 0.688
# epoch no. 122 : loss = 0.337, acc = 0.781
# epoch no. 123 : loss = 0.399, acc = 0.875
# epoch no. 124 : loss = 0.436, acc = 0.781
# epoch no. 125 : loss = 0.437, acc = 0.750
# epoch no. 126 : loss = 0.288, acc = 0.875
# epoch no. 127 : loss = 0.424, acc = 0.781
# epoch no. 128 : loss = 0.424, acc = 0.781
# epoch no. 129 : loss = 0.408, acc = 0.750
# epoch no. 130 : loss = 0.359, acc = 0.812
# epoch no. 131 : loss = 0.351, acc = 0.875
# epoch no. 132 : loss = 0.449, acc = 0.719
# epoch no. 133 : loss = 0.397, acc = 0.719
# epoch no. 134 : loss = 0.450, acc = 0.812
# epoch no. 135 : loss = 0.305, acc = 0.844
# epoch no. 136 : loss = 0.381, acc = 0.781
# epoch no. 137 : loss = 0.504, acc = 0.844
# epoch no. 138 : loss = 0.535, acc = 0.656
# epoch no. 139 : loss = 0.450, acc = 0.719
# epoch no. 140 : loss = 0.201, acc = 0.938
# epoch no. 141 : loss = 0.402, acc = 0.781
# epoch no. 142 : loss = 0.255, acc = 0.875
# epoch no. 143 : loss = 0.410, acc = 0.719
# epoch no. 144 : loss = 0.439, acc = 0.812
# epoch no. 145 : loss = 0.307, acc = 0.844
# epoch no. 146 : loss = 0.491, acc = 0.781
# epoch no. 147 : loss = 0.621, acc = 0.656
# epoch no. 148 : loss = 0.363, acc = 0.719
# epoch no. 149 : loss = 0.378, acc = 0.781
# epoch no. 150 : loss = 0.362, acc = 0.781
# epoch no. 151 : loss = 0.438, acc = 0.750
# epoch no. 152 : loss = 0.528, acc = 0.719
# epoch no. 153 : loss = 0.465, acc = 0.812
# epoch no. 154 : loss = 0.501, acc = 0.750
# epoch no. 155 : loss = 0.572, acc = 0.625
# epoch no. 156 : loss = 0.472, acc = 0.719
# epoch no. 157 : loss = 0.523, acc = 0.688
# epoch no. 158 : loss = 0.547, acc = 0.750
# epoch no. 159 : loss = 0.355, acc = 0.844
# epoch no. 160 : loss = 0.498, acc = 0.750
# epoch no. 161 : loss = 0.505, acc = 0.750
# epoch no. 162 : loss = 0.532, acc = 0.688
# epoch no. 163 : loss = 0.503, acc = 0.781
# epoch no. 164 : loss = 0.335, acc = 0.844
# epoch no. 165 : loss = 0.369, acc = 0.875
# epoch no. 166 : loss = 0.391, acc = 0.844
# epoch no. 167 : loss = 0.495, acc = 0.656
# epoch no. 168 : loss = 0.335, acc = 0.844
# epoch no. 169 : loss = 0.350, acc = 0.812
# epoch no. 170 : loss = 0.292, acc = 0.906
# epoch no. 171 : loss = 0.421, acc = 0.750
# epoch no. 172 : loss = 0.318, acc = 0.844
# epoch no. 173 : loss = 0.548, acc = 0.688
# epoch no. 174 : loss = 0.598, acc = 0.656
# epoch no. 175 : loss = 0.549, acc = 0.688
# epoch no. 176 : loss = 0.398, acc = 0.719
# epoch no. 177 : loss = 0.301, acc = 0.812
# epoch no. 178 : loss = 0.424, acc = 0.812
# epoch no. 179 : loss = 0.263, acc = 0.844
# epoch no. 180 : loss = 0.427, acc = 0.750
# epoch no. 181 : loss = 0.461, acc = 0.750
# epoch no. 182 : loss = 0.309, acc = 0.875
# epoch no. 183 : loss = 0.401, acc = 0.844
# epoch no. 184 : loss = 0.402, acc = 0.750
# epoch no. 185 : loss = 0.395, acc = 0.844
# epoch no. 186 : loss = 0.357, acc = 0.812
# epoch no. 187 : loss = 0.486, acc = 0.719
# epoch no. 188 : loss = 0.301, acc = 0.844
# epoch no. 189 : loss = 0.495, acc = 0.750
# epoch no. 190 : loss = 0.358, acc = 0.812
# epoch no. 191 : loss = 0.455, acc = 0.719
# epoch no. 192 : loss = 0.639, acc = 0.656
# epoch no. 193 : loss = 0.422, acc = 0.875
# epoch no. 194 : loss = 0.421, acc = 0.750
# epoch no. 195 : loss = 0.552, acc = 0.719
# epoch no. 196 : loss = 0.402, acc = 0.750
# epoch no. 197 : loss = 0.320, acc = 0.875
# epoch no. 198 : loss = 0.340, acc = 0.812
# epoch no. 199 : loss = 0.358, acc = 0.844
# epoch no. 200 : loss = 0.535, acc = 0.781
